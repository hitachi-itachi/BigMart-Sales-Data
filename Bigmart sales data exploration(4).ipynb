# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
bigmart_sales = pd.read_csv('Train.csv')
bigmart_sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
bigmart_sales.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
bigmart_sales.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
""" we want to draw correlation to see if:
fat content makes a difference in sale
whether outlet tier makes a difference in sale 
outlet size makes a difference in sale 
"""
# Out:
# ' we want to draw correlation to see if:\nfat content makes a difference in sale\nwhether outlet tier makes a difference in sale \noutlet size makes a difference in sale \n'

# %%
bigmart_sales[bigmart_sales["Item_Weight"].isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
bigmart_sales.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
bigmart_sales.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
 bigmart_sales['Item_Weight'] = bigmart_sales['Item_Weight'].fillna(8.773750) # Fill the missing value with median value

# %%
bigmart_sales.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
bigmart_sales['Outlet_Size'].value_counts() #Medium is the most common here
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
bigmart_sales['Outlet_Size'] = bigmart_sales['Outlet_Size'].fillna("Medium") #Fill the missing column with the most common value

# %%
bigmart_sales.to_csv('file_name.csv', index=False)

# %%
bigmart_sales.hist(figsize = (20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
import matplotlib.pyplot as plt

x = bigmart_sales['Outlet_Establishment_Year']
y = bigmart_sales['Item_Weight']
plt.bar(x, y)
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Item_Weight')
plt.title('Bar Chart Example')
plt.show()

# %%
x = bigmart_sales['Outlet_Establishment_Year']
y = bigmart_sales['Item_Outlet_Sales']
plt.bar(x, y)
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Item_Outlet_Sales')
plt.title('Bar Chart Example')
plt.show()

# %%
grouped_data = bigmart_sales.groupby(["Outlet_Establishment_Year", "Item_Outlet_Sales"])

# %%
mean_sales = grouped_data["Item_Outlet_Sales"].mean()
mean_sales
# Out:
# Outlet_Establishment_Year  Item_Outlet_Sales
# 1985                       33.9558                33.9558
#                            34.6216                34.6216
#                            36.6190                36.6190
#                            37.2848                37.2848
#                            37.9506                37.9506
#                                                   ...
# 2009                       6359.7216            6359.7216
#                            6439.6176            6439.6176
#                            6611.3940            6611.3940
#                            6729.9064            6729.9064
#                            6768.5228            6768.5228
# Name: Item_Outlet_Sales, Length: 7063, dtype: float64

# %%
x = bigmart_sales['Item_Type']
y = bigmart_sales["Item_Outlet_Sales"]
fig = plt.figure()
plt.bar(x, y)
plt.xlabel('Item_Type')
plt.ylabel('Item_Outlet_Sales')
plt.title('Bar Chart Example')
plt.xlabel("X-axis Label")
plt.figure(figsize=(20, 30))
#plt.subplots_adjust(bottom=0.2)
plt.show()

# %%
#household item has the most sales
#other has the least sales

# %%
#identifying outliers

bigmart_sales[['Item_Type', 'Item_Outlet_Sales']].plot(kind = 'scatter', x = 'Item_Type', y = 'Item_Outlet_Sales', figsize = (25,10))
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
bigmart_sales.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.156632         0.066132   140.992782                1997.831867
# std       4.497982         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      11.000000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
bigmart_sales.plot(kind='box',subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.show()

# %%
stats_alive = bigmart_sales.groupby('Item_Type')['Item_Outlet_Sales'].describe().reset_index()[['Item_Type','25%','75%']] #shrink em to 25 percentile and 75 percentile
stats_alive
# Out:
#                 Item_Type        25%         75%
# 0            Baking Goods  705.08220  2823.82425
# 1                  Breads  968.73900  3145.90500
# 2               Breakfast  679.11600  2970.30025
# 3                  Canned  952.09400  3101.29640
# 4                   Dairy  788.97300  3296.20935
# 5            Frozen Foods  808.94700  3079.49145
# 6   Fruits and Vegetables  884.84820  3227.13260
# 7             Hard Drinks  834.91320  3071.33540
# 8      Health and Hygiene  758.84555  2884.57850
# 9               Household  853.38915  3236.78670
# 10                   Meat  782.98080  3036.04800
# 11                 Others  790.97040  2719.79300
# 12                Seafood  473.38380  3589.32780
# 13            Snack Foods  918.80400  3143.57470
# 14            Soft Drinks  771.66220  2759.07520
# 15          Starchy Foods  958.75200  3592.65680

# %%
stats_Visibility = bigmart_sales.groupby('Item_Type')['Item_Visibility'].describe().reset_index()[['Item_Type','25%','75%']] #shrink em to 25 percentile and 75 percentile
stats_Visibility
# Out:
#                 Item_Type       25%       75%
# 0            Baking Goods  0.031402  0.099827
# 1                  Breads  0.024612  0.092679
# 2               Breakfast  0.058496  0.121127
# 3                  Canned  0.027477  0.102408
# 4                   Dairy  0.031291  0.101968
# 5            Frozen Foods  0.026482  0.092676
# 6   Fruits and Vegetables  0.030059  0.100441
# 7             Hard Drinks  0.030711  0.086777
# 8      Health and Hygiene  0.022870  0.076915
# 9               Household  0.024718  0.090561
# 10                   Meat  0.022588  0.085275
# 11                 Others  0.019592  0.090649
# 12                Seafood  0.031285  0.129620
# 13            Snack Foods  0.029539  0.099105
# 14            Soft Drinks  0.024962  0.094603
# 15          Starchy Foods  0.025898  0.098839

# %%
stats_alive.columns = stats_alive.columns.str.replace('25%','Item_Outlet_Sales_25%')
stats_alive.columns = stats_alive.columns.str.replace('75%','Item_Outlet_Sales_75%')
stats_alive
# Out:
#                 Item_Type  Item_Outlet_Sales_25%  Item_Outlet_Sales_75%
# 0            Baking Goods              705.08220             2823.82425
# 1                  Breads              968.73900             3145.90500
# 2               Breakfast              679.11600             2970.30025
# 3                  Canned              952.09400             3101.29640
# 4                   Dairy              788.97300             3296.20935
# 5            Frozen Foods              808.94700             3079.49145
# 6   Fruits and Vegetables              884.84820             3227.13260
# 7             Hard Drinks              834.91320             3071.33540
# 8      Health and Hygiene              758.84555             2884.57850
# 9               Household              853.38915             3236.78670
# 10                   Meat              782.98080             3036.04800
# 11                 Others              790.97040             2719.79300
# ...

# %%
stats_Visibility.columns = stats_Visibility.columns.str.replace('25%','Item_Visiblity_25%')
stats_Visibility.columns = stats_Visibility.columns.str.replace('75%','Item_Visbility_75%')
stats_Visibility
# Out:
#                 Item_Type  Item_Visiblity_25%  Item_Visbility_75%
# 0            Baking Goods            0.031402            0.099827
# 1                  Breads            0.024612            0.092679
# 2               Breakfast            0.058496            0.121127
# 3                  Canned            0.027477            0.102408
# 4                   Dairy            0.031291            0.101968
# 5            Frozen Foods            0.026482            0.092676
# 6   Fruits and Vegetables            0.030059            0.100441
# 7             Hard Drinks            0.030711            0.086777
# 8      Health and Hygiene            0.022870            0.076915
# 9               Household            0.024718            0.090561
# 10                   Meat            0.022588            0.085275
# 11                 Others            0.019592            0.090649
# 12                Seafood            0.031285            0.129620
# ...

# %%
#created bigmart subset 

bigmart_sales_subset = bigmart_sales[["Item_Visibility","Item_Type","Item_MRP","Outlet_Size","Outlet_Location_Type","Outlet_Type", "Item_Outlet_Sales"]]

# %%
#stats_alive = bigmart_sales_subset.groupby('Item_Type')['Item_Outlet_Sales'].describe().reset_index()[['Item_Type','Item_Outlet_Sales_25%','Item_Outlet_Sales_75%']]
#stats_alive

# %%
bigmart_sales_subset = bigmart_sales_subset.merge(stats_alive, on ='Item_Type', how = 'left')
bigmart_sales_subset
# Out:
#       Item_Visibility              Item_Type  Item_MRP Outlet_Size  \
# 0            0.016047                  Dairy  249.8092      Medium
# 1            0.019278            Soft Drinks   48.2692      Medium
# 2            0.016760                   Meat  141.6180      Medium
# 3            0.000000  Fruits and Vegetables  182.0950      Medium
# 4            0.000000              Household   53.8614        High
# ...               ...                    ...       ...         ...
# 8518         0.056783            Snack Foods  214.5218        High
# 8519         0.046982           Baking Goods  108.1570      Medium
# 8520         0.035186     Health and Hygiene   85.1224       Small
# 8521         0.145221            Snack Foods  103.1332      Medium
# 8522         0.044878            Soft Drinks   75.4670       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0                  Tier 1  Supermarket Type1          3735.1380
# ...

# %%
bigmart_sales_subset = bigmart_sales_subset.merge(stats_Visibility, on ='Item_Type', how = 'left')
bigmart_sales_subset
# Out:
#       Item_Visibility              Item_Type  Item_MRP Outlet_Size  \
# 0            0.016047                  Dairy  249.8092      Medium
# 1            0.019278            Soft Drinks   48.2692      Medium
# 2            0.016760                   Meat  141.6180      Medium
# 3            0.000000  Fruits and Vegetables  182.0950      Medium
# 4            0.000000              Household   53.8614        High
# ...               ...                    ...       ...         ...
# 8518         0.056783            Snack Foods  214.5218        High
# 8519         0.046982           Baking Goods  108.1570      Medium
# 8520         0.035186     Health and Hygiene   85.1224       Small
# 8521         0.145221            Snack Foods  103.1332      Medium
# 8522         0.044878            Soft Drinks   75.4670       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0                  Tier 1  Supermarket Type1          3735.1380
# ...

# %%
mask = bigmart_sales_subset['Item_Outlet_Sales']<bigmart_sales_subset['Item_Outlet_Sales_25%']
bigmart_sales_subset['Item_Outlet_Sales'] = bigmart_sales_subset['Item_Outlet_Sales_25%']

mask = bigmart_sales_subset['Item_Outlet_Sales']>bigmart_sales_subset['Item_Outlet_Sales_75%']
bigmart_sales_subset['Item_Outlet_Sales'] = bigmart_sales_subset['Item_Outlet_Sales_75%']

# %%
mask = bigmart_sales_subset['Item_Visibility']<bigmart_sales_subset['Item_Visiblity_25%']
bigmart_sales_subset['Item_Visibility'] = bigmart_sales_subset['Item_Visiblity_25%']

mask = bigmart_sales_subset['Item_Visibility']>bigmart_sales_subset['Item_Visbility_75%']
bigmart_sales_subset['Item_Visibility'] = bigmart_sales_subset['Item_Visbility_75%']

# %%
bigmart_sales_subset.plot(kind='box',subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.show()
